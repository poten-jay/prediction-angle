# %% [markdown]
# # Lomin Project - 이미지 회전 각도 예측
#
# ## Prediction angle
# ---

# %% [markdown]
# ## 목표
#
# #### 이미지 회전 학습을 통해 target 이미지가 어느정도 회전해 있는지 각도를 예측
#
# ---

# %% [markdown]
# ## 사용이미지
#
# 주어진 합성 이미지 활용

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 전처리
#
# ### 신규 이미지는 xml 을 다시 만들어 줘야 함

# %%
DATA_PATH = 'D:/coding/data_set/lomin/train_copy3'

# %% [markdown]
# ---

# %% [markdown]
# 경로
# https://ichi.pro/ko/opencvleul-sayonghayeo-tegseuteu-imijileul-jadong-eulo-giulgi-bojeong-ttogbalo-haneun-bangbeob-176759562404831

# %%
import cv2
import numpy as np
import PIL
from PIL import ImageDraw
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Calculate skew angle of an image
def getSkewAngle(cvImage) -> float:
    # Prep image, copy, convert to gray scale, blur, and threshold
    newImage = cvImage.copy()
    gray = cv2.cvtColor(newImage, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (9, 9), 0)
    thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

    # Apply dilate to merge text into meaningful lines/paragraphs.
    # Use larger kernel on X axis to merge characters into single line, cancelling out any spaces.
    # But use smaller kernel on Y axis to separate between different blocks of text
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (30, 5))
    dilate = cv2.dilate(thresh, kernel, iterations=5)

    # Find all contours
    contours, hierarchy = cv2.findContours(dilate, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key = cv2.contourArea, reverse = True)

    # Find largest contour and surround in min area box
    largestContour = contours[0]
    minAreaRect = cv2.minAreaRect(largestContour)

    # Determine the angle. Convert it to the value that was originally used to obtain skewed image
    angle = minAreaRect[-1]
    if angle < -45:
        angle = 90 + angle
    return -1.0 * angle

# %%
# Rotate the image around its center
def rotateImage(cvImage, angle: float):
    newImage = cvImage.copy()
    (h, w) = newImage.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    newImage = cv2.warpAffine(newImage, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return newImage

# Deskew image
def deskew(cvImage):
    angle = getSkewAngle(cvImage)
    return rotateImage(cvImage, -1.0 * angle)

# %%
## 경로 설정
n_img = 'D:/coding/data_set/lomin/train_copy3/'
one_img = os.listdir(n_img)[1]

cvImage = cv2.imread(n_img + one_img)

# %%
## 원본 그림
path = n_img + one_img
print(path)
img_show(path)
# Out:
# D:/coding/data_set/lomin/train_copy3/000001_33.png

# %%
## 원본 이미지 회전 시키기

angle = 25
rotateImage(cvImage, angle)

img_array(rotateImage(cvImage, angle))

# %%
## 이미지 회전 예측
getSkewAngle(rotateImage(cvImage, angle)) 

getSkewAngle(cvImage)
# Out:
# -0.0

# %%
## 예측치 많큼 이미지 역회전

deskew(rotateImage(cvImage, angle))

img_array(deskew(rotateImage(cvImage, angle)))

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 모델 구성

# %%
import os
import gc
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ## 드라이브 마운트

# from google.colab import drive
# drive.mount('/content/drive/')

# %% [markdown]
# ### 파일 로드 및 확인

# %%
os.listdir(DATA_PATH)
# Out:
# ['desktop.ini', 'test', 'test_angle', 'train', 'train_angle']

# %% [markdown]
# ---
# (통합폴더 (패스))

# %%
import pandas as pd

# train 데이터 프레임 만들기
df_train = pd.DataFrame(columns=['img_file', 'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class'])
df_test = pd.DataFrame(columns=['img_file', 'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class'])

# %%
# %%time
## 테이터 프레임에 xml 정보 추가 (통합 폴더)

import imgaug as ia
import os
from imgaug import augmenters as iaa
import xml.etree.ElementTree as ET

ia.seed(1)

# train dir
dir = DATA_PATH + '/train_angle/'

# test dir
# dir = DATA_PATH + '/test_angle/'

     
## 폴더안에 있는 모든 xml 파일 이름 가져오기
file_list = os.listdir(dir)
xml_list = []

for file in file_list:
    if '.xml' in file:
        xml_list.append(file)

## 모든 .xml파일에 대해 수정
for xml_file in xml_list:
    target_path = dir + xml_file

    tree = ET.parse(target_path)
    root = tree.getroot()
    # bounding_box_list = []

    file_name = root.find('filename').text
    object_label = root.find('object/name').text
    x_min = int(root.find('object/bndbox/xmin').text)
    y_min = int(root.find('object/bndbox/ymin').text)
    x_max = int(root.find('object/bndbox/xmax').text)
    y_max = int(root.find('object/bndbox/ymax').text)
            
    # bounding_box = [file_name, x_min, y_min, x_max, y_max, object_label]

    # trian 데이터 프레임에 추가하기
    df_train = df_train.append(pd.DataFrame([[file_name, x_min, y_min, x_max, y_max, object_label]], 
                                            columns=['img_file', 'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class']),
                                            ignore_index=True)
    
    # # val 데이터 프레임에 추가하기
    # df_test = df_test.append(pd.DataFrame([[file_name, x_min, y_min, x_max, y_max, object_label]], 
    #                                         columns=['img_file', 'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class']),
    #                                         ignore_index=True)
# Out:
# Wall time: 3min 46s

# %%
# %%time
## 테이터 프레임에 xml 정보 추가 (통합 폴더)

import imgaug as ia
import os
from imgaug import augmenters as iaa
import xml.etree.ElementTree as ET

ia.seed(1)

# train dir
# dir = DATA_PATH + '/train_angle/'

# test dir
dir = DATA_PATH + '/test_angle/'

     
## 폴더안에 있는 모든 xml 파일 이름 가져오기
file_list = os.listdir(dir)
xml_list = []

for file in file_list:
    if '.xml' in file:
        xml_list.append(file)

## 모든 .xml파일에 대해 수정
for xml_file in xml_list:
    target_path = dir + xml_file

    tree = ET.parse(target_path)
    root = tree.getroot()
    # bounding_box_list = []

    file_name = root.find('filename').text
    object_label = root.find('object/name').text
    x_min = int(root.find('object/bndbox/xmin').text)
    y_min = int(root.find('object/bndbox/ymin').text)
    x_max = int(root.find('object/bndbox/xmax').text)
    y_max = int(root.find('object/bndbox/ymax').text)
            
    # bounding_box = [file_name, x_min, y_min, x_max, y_max, object_label]

    # # trian 데이터 프레임에 추가하기
    # df_train = df_train.append(pd.DataFrame([[file_name, x_min, y_min, x_max, y_max, object_label]], 
    #                                         columns=['img_file', 'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class']),
    #                                         ignore_index=True)
    
    # val 데이터 프레임에 추가하기
    df_test = df_test.append(pd.DataFrame([[file_name, x_min, y_min, x_max, y_max, object_label]], 
                                            columns=['img_file', 'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class']),
                                            ignore_index=True)
# Out:
# Wall time: 8.44 s

# %% [markdown]
# ---

# %%
df_train1 = pd.DataFrame.copy(df_train)
df_train1
# Out:
#              img_file bbox_x1 bbox_y1 bbox_x2 bbox_y2 class
# 0      000000_126.png      10     395    1643    1943   126
# 1      000000_190.png     246     431    1407    1907   190
# 2      000000_350.png     246     431    1407    1907   350
# 3       000000_41.png      33     356    1620    1982    41
# 4      000001_194.png     207     408    1446    1930   194
# ...               ...     ...     ...     ...     ...   ...
# 35995  011946_326.png      62     352    1590    1985   326
# 35996   011947_15.png     198     403    1455    1935    15
# 35997  011947_156.png     123     368    1528    1970   156
# 35998   011947_31.png      79     355    1574    1984    31
# 35999   011947_66.png      25     467    1627    1872    66
#
# [36000 rows x 6 columns]

# %%
df_test1 = pd.DataFrame.copy(df_test)
df_test1
# Out:
#             img_file bbox_x1 bbox_y1 bbox_x2 bbox_y2 class
# 0     000024_261.png      94     599    1559    1739   261
# 1     000028_176.png     309     471    1344    1867   176
# 2     000028_210.png      84     356    1569    1982   210
# 3     000028_329.png      79     355    1574    1983   329
# 4     000053_214.png      62     353    1591    1985   214
# ...              ...     ...     ...     ...     ...   ...
# 1795   011921_95.png     121     641    1531    1698    95
# 1796  011940_149.png      78     355    1573    1984   149
# 1797  011940_199.png     162     385    1489    1953   199
# 1798   011940_32.png      73     354    1580    1985    32
# 1799  011940_333.png     103     361    1550    1977   333
#
# [1800 rows x 6 columns]

# %% [markdown]
# ---

# %%
# 이미지 폴더 경로
TRAIN_IMG_PATH = os.path.join(DATA_PATH, 'train_angle')
TEST_IMG_PATH = os.path.join(DATA_PATH, 'test_angle')

# IMG_SIZE
img_size = (224, 224)
img_size = (224, 224)

# %% [markdown]
# ___

# %% [markdown]
# ## 이미지 확인

# %%
import PIL
from PIL import ImageDraw

# %%
## 랜덤하게 8장 사진을 확인
tmp_imgs = df_train['img_file'].sample(n=8, random_state=42)
plt.figure(figsize=(20, 12))

for num, f_name in enumerate(tmp_imgs):
    img = PIL.Image.open(os.path.join(TRAIN_IMG_PATH, f_name))
    plt.subplot(2, 4, num + 1)
    plt.title(f_name)
    plt.imshow(img)
    plt.axis('off')

# %%
## 박스 처리

def draw_rect(drawcontext, pos, outline=None, width=0):
    (x1, y1) = (pos[0], pos[1])
    (x2, y2) = (pos[2], pos[3])
    points = (x1, y1), (x2, y1), (x2, y2), (x1, y2), (x1, y1)
    drawcontext.line(points, fill=outline, width=width)

# %%
## train data 바운딩 처리

def make_boxing_img_train(img_name) :
    PATH = TRAIN_IMG_PATH
    data = df_train

    img = PIL.Image.open(os.path.join(PATH, img_name))
    pos = data.loc[data["img_file"] == img_name, \
                   ['bbox_x1','bbox_y1', 'bbox_x2', 'bbox_y2']].values.reshape(-1)
    draw = ImageDraw.Draw(img)
    draw_rect(draw, pos, outline='red', width=10)
    
    return img

# %%
## test data 바운딩 처리

def make_boxing_img_test(img_name) :
    PATH = TEST_IMG_PATH
    data = df_test

    img = PIL.Image.open(os.path.join(PATH, img_name))
    pos = data.loc[data["img_file"] == img_name, \
                   ['bbox_x1','bbox_y1', 'bbox_x2', 'bbox_y2']].values.reshape(-1)
    draw = ImageDraw.Draw(img)
    draw_rect(draw, pos, outline='red', width=10)
    
    return img

# %%
## 확인하고 싶은 이미지 번호 입력
f_name = "000003_242.png"

plt.figure(figsize=(20,10))

## 원본 이미지
plt.subplot(1, 2, 1)
origin_img = PIL.Image.open(os.path.join(TRAIN_IMG_PATH, f_name))
plt.title("Original Image - {}".format(f_name))
plt.imshow(origin_img)
plt.axis('off')

## Bounding Box 처리 된 이미지
plt.subplot(1, 2, 2)
boxing = make_boxing_img_train(f_name)
plt.title("Boxing Image - {}".format(f_name))
plt.imshow(boxing)
plt.axis('off')

plt.show()

# %% [markdown]
# ## 이미지 resize 하기

# %%
## train 이미지 resize

def crop_resize_boxing_img_train(img_name, margin=16, size=(224, 224)) :
    PATH = TRAIN_IMG_PATH
    data = df_train
        
    img = PIL.Image.open(os.path.join(PATH, img_name))
    # pos = data.loc[data["img_file"] == img_name, \
    #                ['bbox_x1','bbox_y1', 'bbox_x2', 'bbox_y2']].values.reshape(-1)
    
    pos = data.loc[data["img_file"] == img_name, \
                ['bbox_x1','bbox_y1', 'bbox_x2', 'bbox_y2']].values.reshape(-1)

    width, height = img.size
    x1 = max(0, pos[0] - margin)
    y1 = max(0, pos[1] - margin)
    x2 = min(pos[2] + margin, width)
    y2 = min(pos[3] + margin, height)

    return img.crop((x1,y1,x2,y2)).resize(size)

# %%
## test 이미지 resize

def crop_resize_boxing_img_test(img_name, margin=16, size=img_size) :
    PATH = TEST_IMG_PATH
    data = df_test
        
    img = PIL.Image.open(os.path.join(PATH, img_name))
    
    # pos = data.loc[data["img_file"] == img_name, \
    #                ['bbox_x1','bbox_y1', 'bbox_x2', 'bbox_y2']].values.reshape(-1)

    pos = data.loc[data["img_file"] == img_name, \
                   ['bbox_x1','bbox_y1', 'bbox_x2', 'bbox_y2']].values.reshape(-1)

    width, height = img.size
    x1 = max(0, pos[0] - margin)
    y1 = max(0, pos[1] - margin)
    x2 = min(pos[2] + margin, width)
    y2 = min(pos[3] + margin, height)

    return img.crop((x1,y1,x2,y2)).resize(size)

# %%
# %%time
## 폴더를 만들고 박스에 맞춰 이미지 resize (train data) 후 폴더에 저장

os.makedirs(os.path.join(DATA_PATH,'train_crop'))

for i, row in df_train.iterrows():
    cropped = crop_resize_boxing_img_train(row['img_file'])
    cropped.save(f"{os.path.join(DATA_PATH, 'train_crop')}/{row['img_file']}")
# Out:
# Wall time: 9min 3s

# %%
# %%time
## 폴더를 만들고 박스에 맞춰 이미지 resize (test data) 후 폴더에 저장

os.makedirs(os.path.join(DATA_PATH, 'test_crop'))

for i, row in df_test.iterrows():
    cropped = crop_resize_boxing_img_test(row['img_file'])
    cropped.save(f"{os.path.join(DATA_PATH,'test_crop')}/{row['img_file']}")
# Out:
# Wall time: 54.5 s

# %%
## crop 이미지 경로 설정

TRAIN_CROP_PATH = os.path.join(DATA_PATH, 'train_crop')
TEST_CROP_PATH = os.path.join(DATA_PATH, 'test_crop')

# %%
## 확인하고 싶은 이미지 번호 입력
f_name = "000021_130.png"

plt.figure(figsize=(20,10))

## 원본 이미지
plt.subplot(1, 3, 1)
origin_img = PIL.Image.open(os.path.join(TRAIN_IMG_PATH, f_name))
plt.title("Original Image - {}".format(f_name))
plt.imshow(origin_img)
plt.axis('off')

## Bounding Box 처리 된 이미지
plt.subplot(1, 3, 2)
boxing = make_boxing_img_train(f_name)
plt.title("Boxing Image - {}".format(f_name))
plt.imshow(boxing)
plt.axis('off')

## crop 된 이미지
plt.subplot(1, 3, 3)
crop = PIL.Image.open(os.path.join(TRAIN_CROP_PATH, f_name))
plt.title("crop - {}".format(f_name))
plt.imshow(crop)
plt.axis('off')

plt.show()

# %%
## crop 된 이미지 확인

tmp_imgs = df_train['img_file'].sample(n=3, random_state=42)
# tmp_imgs = df_train['img_file'][100:103]
plt.figure(figsize=(12,20))

for num, f_name in enumerate(tmp_imgs):
    img = PIL.Image.open(os.path.join(TRAIN_IMG_PATH, f_name))
    plt.subplot(3, 2, 2*num + 1)
    plt.title(f_name)
    plt.imshow(img)
    plt.axis('off')
    
    img = PIL.Image.open(os.path.join(TRAIN_CROP_PATH, f_name))
    plt.subplot(3, 2, 2*num + 2)
    plt.title(f_name + "crop")
    plt.imshow(img)
    plt.axis('off')

# %% [markdown]
# ## 모델링

# %%
## train, val, test set 나눠주기

from sklearn.model_selection import train_test_split

## class 를 string 으로 바꿔주고 좌표들을 지워준다.
df_train["class"] = df_train["class"].astype('str')

df_train = df_train[['img_file', 'class']]
df_test = df_test[['img_file']]

its = np.arange(df_train.shape[0])
train_idx, val_idx = train_test_split(its, train_size = 0.7, random_state=42)

X_train = df_train.iloc[train_idx, :]
X_val = df_train.iloc[val_idx, :]

print(X_train.shape)
print(X_val.shape)
print(df_test.shape)
# Out:
# (7559, 2)
# (3241, 2)
# (1080, 1)
# C:\ProgramData\Anaconda3\envs\lomin\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(X_val['class'].unique())
# Out:
# 360

# %% [markdown]
# 모델링은 keras의 generator 들을 이용하면 쉽게 만들 수 있다.

# %%
import tensorflow as tf
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
## 데이터 제네레이터 구성하기

## 파라미터 설정
## https://keras.io/api/preprocessing/image/

nb_train_samples = len(X_train)
nb_validation_samples = len(X_val)
nb_test_samples = len(df_test)
batch_size = 32

# %%
## 입력이미지의 데이터 증강 (Data Augmentation)
train_datagen = ImageDataGenerator(
    width_shift_range=0.2,
    height_shift_range=0.2,
    brightness_range=[0.2,1.0],
    zoom_range=[0.5,0.1],
    preprocessing_function=preprocess_input
)

# val_datagen = ImageDataGenerator(rescale=1. / 255)
# train_datagen = ImageDataGenerator(rescale=1. / 255)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
## 제네레이터 설정
##.flow_from_dataframe
##.flow_from_directory

# Make Generator
train_generator = train_datagen.flow_from_dataframe(
    dataframe=X_train, 
    directory=TRAIN_CROP_PATH,
    x_col = 'img_file',
    y_col = 'class',
    target_size = img_size,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=batch_size,
    seed=42
)

validation_generator = val_datagen.flow_from_dataframe(
    dataframe=X_val, 
    directory=TRAIN_CROP_PATH,
    x_col='img_file',
    y_col='class',
    target_size=img_size,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=False
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=df_test,
    directory=TEST_CROP_PATH,
    x_col='img_file',
    y_col=None,
    target_size= img_size,
    color_mode='rgb',
    class_mode=None,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 7559 validated image filenames belonging to 360 classes.
# Found 3241 validated image filenames belonging to 360 classes.
# Found 1080 validated image filenames.

# %%
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.applications.resnet_v2 import ResNet50V2

# %%
## MobileNet 으로  base model을 만든다.

# weights='imagenet' : 이미지 넷에 트레이닝 된 모델을 불러옴

IMG_SHAPE = img_size + (3, )

BaseModel = MobileNet(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)

# BaseModel = ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)

# BaseModel = ResNet50V2(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)

model = Sequential()
model.add(BaseModel)
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='sigmoid', kernel_initializer='he_normal'))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(16, activation='sigmoid'))
model.add(Dense(360, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_12 (Dense)             (None, 360)               6120
# =================================================================
# Total params: 3,541,144
# Trainable params: 3,519,256
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
## 모델 컴파일 하기
from sklearn.metrics import f1_score

def micro_f1(y_true, y_pred):
    return f1_score(y_true, y_pred, average='micro')

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

# %%
def get_steps(num_samples, batch_size):
    if (num_samples % batch_size) > 0 :
        return (num_samples // batch_size) + 1
    else :
        return num_samples // batch_size

# %%
## 체크포인트 설정

## monitor : val_acc 를 기준으로 저장한다.
## verbose : 1 일 경우 모델이 저장 됨을 표시

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

filepath = "my_mobilenet_model_{val_acc:.2f}_{val_loss:.4f}.h5"

checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True)
#es = EarlyStopping(monitor='val_acc', min_delta=0, patience=3, verbose=1, mode='auto')

callbackList = [checkpoint]

# %%
# %%time

history = model.fit_generator(
    train_generator,
    steps_per_epoch = get_steps(nb_train_samples, batch_size),
    epochs=150,
    validation_data = validation_generator,
    validation_steps = get_steps(nb_validation_samples, batch_size),
    callbacks = callbackList
)
gc.collect()
# Out:
# Epoch 1/150
#   2/237 [..............................] - ETA: 52s - loss: 5.8965 - acc: 0.0156WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0850s vs `on_train_batch_end` time: 0.1700s). Check your callbacks.
# 237/237 [==============================] - ETA: 0s - loss: 5.8960 - acc: 0.0030
# Epoch 00001: val_acc improved from -inf to 0.00154, saving model to my_mobilenet_model_0.00_5.8953.h5
# 237/237 [==============================] - 82s 346ms/step - loss: 5.8960 - acc: 0.0030 - val_loss: 5.8953 - val_acc: 0.0015
# Epoch 2/150
# 237/237 [==============================] - ETA: 0s - loss: 5.8856 - acc: 0.0026
# Epoch 00002: val_acc did not improve from 0.00154
# 237/237 [==============================] - 75s 318ms/step - loss: 5.8856 - acc: 0.0026 - val_loss: 5.9046 - val_acc: 0.0015
# Epoch 3/150
# 237/237 [==============================] - ETA: 0s - loss: 5.8714 - acc: 0.0033
# Epoch 00003: val_acc improved from 0.00154 to 0.00185, saving model to my_mobilenet_model_0.00_5.9048.h5
# 237/237 [==============================] - 76s 320ms/step - loss: 5.8714 - acc: 0.0033 - val_loss: 5.9048 - val_acc: 0.0019
# Epoch 4/150
# 237/237 [==============================] - ETA: 0s - loss: 5.8249 - acc: 0.0049
# Epoch 00004: val_acc did not improve from 0.00185
# 237/237 [==============================] - 75s 317ms/step - loss: 5.8249 - acc: 0.0049 - val_loss: 5.9851 - val_acc: 0.0015
# Epoch 5/150
# 237/237 [==============================] - ETA: 0s - loss: 5.7637 - acc: 0.0045
# Epoch 00005: val_acc did not improve from 0.00185
# 237/237 [==============================] - 78s 329ms/step - loss: 5.7637 - acc: 0.0045 - val_loss: 6.0661 - val_acc: 0.0012
# Epoch 6/150
# 237/237 [==============================] - ETA: 0s - loss: 5.7122 - acc: 0.0042
# Epoch 00006: val_acc did not improve from 0.00185
# 237/237 [==============================] - 76s 319ms/step - loss: 5.7122 - acc: 0.0042 - val_loss: 6.0088 - val_acc: 0.0012
# Epoch 7/150
# 237/237 [==============================] - ETA: 0s - loss: 5.6896 - acc: 0.0052
# Epoch 00007: val_acc did not improve from 0.00185
# 237/237 [==============================] - 75s 318ms/step - loss: 5.6896 - acc: 0.0052 - val_loss: 5.9633 - val_acc: 0.0015
# Epoch 8/150
# 237/237 [==============================] - ETA: 0s - loss: 5.6512 - acc: 0.0049
# Epoch 00008: val_acc improved from 0.00185 to 0.00247, saving model to my_mobilenet_model_0.00_5.9437.h5
# 237/237 [==============================] - 76s 319ms/step - loss: 5.6512 - acc: 0.0049 - val_loss: 5.9437 - val_acc: 0.0025
# Epoch 9/150
# 237/237 [==============================] - ETA: 0s - loss: 5.5789 - acc: 0.0056
# Epoch 00009: val_acc did not improve from 0.00247
# 237/237 [==============================] - 75s 318ms/step - loss: 5.5789 - acc: 0.0056 - val_loss: 5.8738 - val_acc: 0.0012
# Epoch 10/150
# 237/237 [==============================] - ETA: 0s - loss: 5.5166 - acc: 0.0046
# Epoch 00010: val_acc did not improve from 0.00247
# 237/237 [==============================] - 76s 319ms/step - loss: 5.5166 - acc: 0.0046 - val_loss: 5.9366 - val_acc: 0.0025
# Epoch 11/150
# 237/237 [==============================] - ETA: 0s - loss: 5.4454 - acc: 0.0064
# Epoch 00011: val_acc did not improve from 0.00247
# 237/237 [==============================] - 75s 318ms/step - loss: 5.4454 - acc: 0.0064 - val_loss: 5.9427 - val_acc: 0.0012
# Epoch 12/150
# 237/237 [==============================] - ETA: 0s - loss: 5.3860 - acc: 0.0090
# Epoch 00012: val_acc improved from 0.00247 to 0.00309, saving model to my_mobilenet_model_0.00_5.7523.h5
# 237/237 [==============================] - 76s 320ms/step - loss: 5.3860 - acc: 0.0090 - val_loss: 5.7523 - val_acc: 0.0031
# Epoch 13/150
# 237/237 [==============================] - ETA: 0s - loss: 5.3248 - acc: 0.0093
# Epoch 00013: val_acc improved from 0.00309 to 0.00339, saving model to my_mobilenet_model_0.00_5.6595.h5
# 237/237 [==============================] - 77s 324ms/step - loss: 5.3248 - acc: 0.0093 - val_loss: 5.6595 - val_acc: 0.0034
# Epoch 14/150
# 237/237 [==============================] - ETA: 0s - loss: 5.2744 - acc: 0.0085
# Epoch 00014: val_acc did not improve from 0.00339
# 237/237 [==============================] - 75s 318ms/step - loss: 5.2744 - acc: 0.0085 - val_loss: 5.5998 - val_acc: 0.0028
# Epoch 15/150
# 237/237 [==============================] - ETA: 0s - loss: 5.2294 - acc: 0.0095
# Epoch 00015: val_acc did not improve from 0.00339
# 237/237 [==============================] - 75s 318ms/step - loss: 5.2294 - acc: 0.0095 - val_loss: 5.4686 - val_acc: 0.0028
# Epoch 16/150
# 237/237 [==============================] - ETA: 0s - loss: 5.1947 - acc: 0.0095
# Epoch 00016: val_acc did not improve from 0.00339
# 237/237 [==============================] - 75s 318ms/step - loss: 5.1947 - acc: 0.0095 - val_loss: 5.4944 - val_acc: 0.0025
# Epoch 17/150
# 237/237 [==============================] - ETA: 0s - loss: 5.1491 - acc: 0.0106
# Epoch 00017: val_acc improved from 0.00339 to 0.00370, saving model to my_mobilenet_model_0.00_5.3261.h5
# 237/237 [==============================] - 76s 320ms/step - loss: 5.1491 - acc: 0.0106 - val_loss: 5.3261 - val_acc: 0.0037
# Epoch 18/150
# 237/237 [==============================] - ETA: 0s - loss: 5.1062 - acc: 0.0128
# Epoch 00018: val_acc did not improve from 0.00370
# 237/237 [==============================] - 75s 317ms/step - loss: 5.1062 - acc: 0.0128 - val_loss: 5.4746 - val_acc: 0.0034
# Epoch 19/150
# 237/237 [==============================] - ETA: 0s - loss: 5.0631 - acc: 0.0127
# Epoch 00019: val_acc did not improve from 0.00370
# 237/237 [==============================] - 75s 317ms/step - loss: 5.0631 - acc: 0.0127 - val_loss: 5.4470 - val_acc: 0.0031
# Epoch 20/150
# 237/237 [==============================] - ETA: 0s - loss: 5.0319 - acc: 0.0148
# Epoch 00020: val_acc improved from 0.00370 to 0.00586, saving model to my_mobilenet_model_0.01_5.4579.h5
# 237/237 [==============================] - 76s 320ms/step - loss: 5.0319 - acc: 0.0148 - val_loss: 5.4579 - val_acc: 0.0059
# Epoch 21/150
# 237/237 [==============================] - ETA: 0s - loss: 5.0106 - acc: 0.0147
# Epoch 00021: val_acc improved from 0.00586 to 0.00741, saving model to my_mobilenet_model_0.01_5.2975.h5
# 237/237 [==============================] - 78s 327ms/step - loss: 5.0106 - acc: 0.0147 - val_loss: 5.2975 - val_acc: 0.0074
# Epoch 22/150
# 237/237 [==============================] - ETA: 0s - loss: 4.9717 - acc: 0.0147
# Epoch 00022: val_acc did not improve from 0.00741
# 237/237 [==============================] - 76s 321ms/step - loss: 4.9717 - acc: 0.0147 - val_loss: 5.2428 - val_acc: 0.0065
# Epoch 23/150
# 237/237 [==============================] - ETA: 0s - loss: 4.9420 - acc: 0.0153
# Epoch 00023: val_acc did not improve from 0.00741
# 237/237 [==============================] - 76s 322ms/step - loss: 4.9420 - acc: 0.0153 - val_loss: 5.4079 - val_acc: 0.0043
# Epoch 24/150
# 237/237 [==============================] - ETA: 0s - loss: 4.9025 - acc: 0.0168
# Epoch 00024: val_acc did not improve from 0.00741
# 237/237 [==============================] - 76s 320ms/step - loss: 4.9025 - acc: 0.0168 - val_loss: 5.7174 - val_acc: 0.0034
# Epoch 25/150
# 237/237 [==============================] - ETA: 0s - loss: 4.8811 - acc: 0.0173
# Epoch 00025: val_acc did not improve from 0.00741
# 237/237 [==============================] - 76s 319ms/step - loss: 4.8811 - acc: 0.0173 - val_loss: 5.5397 - val_acc: 0.0056
# Epoch 26/150
# 237/237 [==============================] - ETA: 0s - loss: 4.8533 - acc: 0.0144
# Epoch 00026: val_acc improved from 0.00741 to 0.00864, saving model to my_mobilenet_model_0.01_5.0843.h5
# 237/237 [==============================] - 76s 320ms/step - loss: 4.8533 - acc: 0.0144 - val_loss: 5.0843 - val_acc: 0.0086
# Epoch 27/150
# 237/237 [==============================] - ETA: 0s - loss: 4.8194 - acc: 0.0179
# Epoch 00027: val_acc did not improve from 0.00864
# 237/237 [==============================] - 76s 320ms/step - loss: 4.8194 - acc: 0.0179 - val_loss: 5.0329 - val_acc: 0.0083
# Epoch 28/150
# 237/237 [==============================] - ETA: 0s - loss: 4.7972 - acc: 0.0181
# Epoch 00028: val_acc did not improve from 0.00864
# 237/237 [==============================] - 76s 319ms/step - loss: 4.7972 - acc: 0.0181 - val_loss: 5.2189 - val_acc: 0.0083
# Epoch 29/150
# 237/237 [==============================] - ETA: 0s - loss: 4.7728 - acc: 0.0172
# Epoch 00029: val_acc did not improve from 0.00864
# 237/237 [==============================] - 76s 321ms/step - loss: 4.7728 - acc: 0.0172 - val_loss: 5.1493 - val_acc: 0.0086
# Epoch 30/150
# 237/237 [==============================] - ETA: 0s - loss: 4.7655 - acc: 0.0191
# Epoch 00030: val_acc did not improve from 0.00864
# 237/237 [==============================] - 76s 322ms/step - loss: 4.7655 - acc: 0.0191 - val_loss: 5.4327 - val_acc: 0.0071
# Epoch 31/150
# 237/237 [==============================] - ETA: 0s - loss: 4.7312 - acc: 0.0187
# Epoch 00031: val_acc improved from 0.00864 to 0.01203, saving model to my_mobilenet_model_0.01_4.9810.h5
# 237/237 [==============================] - 76s 321ms/step - loss: 4.7312 - acc: 0.0187 - val_loss: 4.9810 - val_acc: 0.0120
# Epoch 32/150
# 237/237 [==============================] - ETA: 0s - loss: 4.7120 - acc: 0.0179
# Epoch 00032: val_acc did not improve from 0.01203
# 237/237 [==============================] - 76s 320ms/step - loss: 4.7120 - acc: 0.0179 - val_loss: 5.1379 - val_acc: 0.0086
# Epoch 33/150
# 237/237 [==============================] - ETA: 0s - loss: 4.7085 - acc: 0.0208
# Epoch 00033: val_acc did not improve from 0.01203
# 237/237 [==============================] - 76s 321ms/step - loss: 4.7085 - acc: 0.0208 - val_loss: 6.2409 - val_acc: 0.0040
# Epoch 34/150
# 237/237 [==============================] - ETA: 0s - loss: 4.6842 - acc: 0.0214
# Epoch 00034: val_acc did not improve from 0.01203
# 237/237 [==============================] - 76s 320ms/step - loss: 4.6842 - acc: 0.0214 - val_loss: 5.1050 - val_acc: 0.0080
# Epoch 35/150
# 237/237 [==============================] - ETA: 0s - loss: 4.6480 - acc: 0.0210
# Epoch 00035: val_acc did not improve from 0.01203
# 237/237 [==============================] - 78s 327ms/step - loss: 4.6480 - acc: 0.0210 - val_loss: 5.1522 - val_acc: 0.0074
# Epoch 36/150
# 237/237 [==============================] - ETA: 0s - loss: 4.6323 - acc: 0.0196
# Epoch 00036: val_acc improved from 0.01203 to 0.01327, saving model to my_mobilenet_model_0.01_4.7122.h5
# 237/237 [==============================] - 77s 325ms/step - loss: 4.6323 - acc: 0.0196 - val_loss: 4.7122 - val_acc: 0.0133
# Epoch 37/150
# 237/237 [==============================] - ETA: 0s - loss: 4.5956 - acc: 0.0226
# Epoch 00037: val_acc did not improve from 0.01327
# 237/237 [==============================] - 77s 324ms/step - loss: 4.5956 - acc: 0.0226 - val_loss: 6.4961 - val_acc: 0.0068
# Epoch 38/150
# 237/237 [==============================] - ETA: 0s - loss: 4.6003 - acc: 0.0204
# Epoch 00038: val_acc did not improve from 0.01327
# 237/237 [==============================] - 76s 322ms/step - loss: 4.6003 - acc: 0.0204 - val_loss: 4.9639 - val_acc: 0.0099
# Epoch 39/150
# 237/237 [==============================] - ETA: 0s - loss: 4.6448 - acc: 0.0202
# Epoch 00039: val_acc did not improve from 0.01327
# 237/237 [==============================] - 76s 321ms/step - loss: 4.6448 - acc: 0.0202 - val_loss: 5.0246 - val_acc: 0.0086
# Epoch 40/150
# 237/237 [==============================] - ETA: 0s - loss: 4.5971 - acc: 0.0230
# Epoch 00040: val_acc did not improve from 0.01327
# 237/237 [==============================] - 76s 321ms/step - loss: 4.5971 - acc: 0.0230 - val_loss: 5.5527 - val_acc: 0.0046
# Epoch 41/150
# 237/237 [==============================] - ETA: 0s - loss: 4.5755 - acc: 0.0214
# Epoch 00041: val_acc did not improve from 0.01327
# 237/237 [==============================] - 76s 321ms/step - loss: 4.5755 - acc: 0.0214 - val_loss: 5.1016 - val_acc: 0.0123
# Epoch 42/150
# 237/237 [==============================] - ETA: 0s - loss: 4.5194 - acc: 0.0251
# Epoch 00042: val_acc did not improve from 0.01327
# 237/237 [==============================] - 76s 321ms/step - loss: 4.5194 - acc: 0.0251 - val_loss: 5.0290 - val_acc: 0.0083
# Epoch 43/150
# 237/237 [==============================] - ETA: 0s - loss: 4.5046 - acc: 0.0253
# Epoch 00043: val_acc did not improve from 0.01327
# 237/237 [==============================] - 76s 320ms/step - loss: 4.5046 - acc: 0.0253 - val_loss: 4.9954 - val_acc: 0.0114
# Epoch 44/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4790 - acc: 0.0249
# Epoch 00044: val_acc improved from 0.01327 to 0.01820, saving model to my_mobilenet_model_0.02_4.7403.h5
# 237/237 [==============================] - 78s 328ms/step - loss: 4.4790 - acc: 0.0249 - val_loss: 4.7403 - val_acc: 0.0182
# Epoch 45/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4943 - acc: 0.0254
# Epoch 00045: val_acc did not improve from 0.01820
# 237/237 [==============================] - 75s 318ms/step - loss: 4.4943 - acc: 0.0254 - val_loss: 4.8390 - val_acc: 0.0120
# Epoch 46/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4547 - acc: 0.0249
# Epoch 00046: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 321ms/step - loss: 4.4547 - acc: 0.0249 - val_loss: 4.7138 - val_acc: 0.0096
# Epoch 47/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4309 - acc: 0.0265
# Epoch 00047: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.4309 - acc: 0.0265 - val_loss: 4.6735 - val_acc: 0.0151
# Epoch 48/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4450 - acc: 0.0263
# Epoch 00048: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.4450 - acc: 0.0263 - val_loss: 4.7567 - val_acc: 0.0120
# Epoch 49/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4219 - acc: 0.0267
# Epoch 00049: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 321ms/step - loss: 4.4219 - acc: 0.0267 - val_loss: 4.7938 - val_acc: 0.0105
# Epoch 50/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4186 - acc: 0.0254
# Epoch 00050: val_acc did not improve from 0.01820
# 237/237 [==============================] - 75s 318ms/step - loss: 4.4186 - acc: 0.0254 - val_loss: 4.7757 - val_acc: 0.0096
# Epoch 51/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4120 - acc: 0.0278
# Epoch 00051: val_acc did not improve from 0.01820
# 237/237 [==============================] - 75s 318ms/step - loss: 4.4120 - acc: 0.0278 - val_loss: 5.4986 - val_acc: 0.0077
# Epoch 52/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3731 - acc: 0.0315
# Epoch 00052: val_acc did not improve from 0.01820
# 237/237 [==============================] - 77s 324ms/step - loss: 4.3731 - acc: 0.0315 - val_loss: 5.3229 - val_acc: 0.0074
# Epoch 53/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3773 - acc: 0.0308
# Epoch 00053: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 321ms/step - loss: 4.3773 - acc: 0.0308 - val_loss: 5.0356 - val_acc: 0.0093
# Epoch 54/150
# 237/237 [==============================] - ETA: 0s - loss: 4.4207 - acc: 0.0259
# Epoch 00054: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 321ms/step - loss: 4.4207 - acc: 0.0259 - val_loss: 5.4331 - val_acc: 0.0111
# Epoch 55/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3443 - acc: 0.0270
# Epoch 00055: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.3443 - acc: 0.0270 - val_loss: 4.9986 - val_acc: 0.0151
# Epoch 56/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3479 - acc: 0.0316
# Epoch 00056: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.3479 - acc: 0.0316 - val_loss: 5.2894 - val_acc: 0.0133
# Epoch 57/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3343 - acc: 0.0304
# Epoch 00057: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.3343 - acc: 0.0304 - val_loss: 4.9035 - val_acc: 0.0117
# Epoch 58/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3817 - acc: 0.0287
# Epoch 00058: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 321ms/step - loss: 4.3817 - acc: 0.0287 - val_loss: 4.8125 - val_acc: 0.0127
# Epoch 59/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3237 - acc: 0.0307
# Epoch 00059: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.3237 - acc: 0.0307 - val_loss: 4.9645 - val_acc: 0.0108
# Epoch 60/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3549 - acc: 0.0302
# Epoch 00060: val_acc did not improve from 0.01820
# 237/237 [==============================] - 77s 324ms/step - loss: 4.3549 - acc: 0.0302 - val_loss: 4.8311 - val_acc: 0.0089
# Epoch 61/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2888 - acc: 0.0295
# Epoch 00061: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.2888 - acc: 0.0295 - val_loss: 4.8340 - val_acc: 0.0127
# Epoch 62/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3858 - acc: 0.0247
# Epoch 00062: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.3858 - acc: 0.0247 - val_loss: 6.4439 - val_acc: 0.0031
# Epoch 63/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3245 - acc: 0.0274
# Epoch 00063: val_acc did not improve from 0.01820
# 237/237 [==============================] - 75s 317ms/step - loss: 4.3245 - acc: 0.0274 - val_loss: 6.0011 - val_acc: 0.0111
# Epoch 64/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2596 - acc: 0.0343
# Epoch 00064: val_acc did not improve from 0.01820
# 237/237 [==============================] - 75s 319ms/step - loss: 4.2596 - acc: 0.0343 - val_loss: 5.0405 - val_acc: 0.0127
# Epoch 65/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2888 - acc: 0.0312
# Epoch 00065: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 319ms/step - loss: 4.2888 - acc: 0.0312 - val_loss: 4.7161 - val_acc: 0.0145
# Epoch 66/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2774 - acc: 0.0327
# Epoch 00066: val_acc did not improve from 0.01820
# 237/237 [==============================] - 75s 318ms/step - loss: 4.2774 - acc: 0.0327 - val_loss: 6.6152 - val_acc: 0.0037
# Epoch 67/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2918 - acc: 0.0304
# Epoch 00067: val_acc did not improve from 0.01820
# 237/237 [==============================] - 76s 320ms/step - loss: 4.2918 - acc: 0.0304 - val_loss: 5.0711 - val_acc: 0.0105
# Epoch 68/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2592 - acc: 0.0335
# Epoch 00068: val_acc improved from 0.01820 to 0.01882, saving model to my_mobilenet_model_0.02_4.8317.h5
# 237/237 [==============================] - 78s 327ms/step - loss: 4.2592 - acc: 0.0335 - val_loss: 4.8317 - val_acc: 0.0188
# Epoch 69/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2101 - acc: 0.0311
# Epoch 00069: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 319ms/step - loss: 4.2101 - acc: 0.0311 - val_loss: 5.4105 - val_acc: 0.0105
# Epoch 70/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2377 - acc: 0.0341
# Epoch 00070: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 320ms/step - loss: 4.2377 - acc: 0.0341 - val_loss: 5.1791 - val_acc: 0.0105
# Epoch 71/150
# 237/237 [==============================] - ETA: 0s - loss: 4.3334 - acc: 0.0291
# Epoch 00071: val_acc did not improve from 0.01882
# 237/237 [==============================] - 77s 325ms/step - loss: 4.3334 - acc: 0.0291 - val_loss: 5.7291 - val_acc: 0.0052
# Epoch 72/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2155 - acc: 0.0324
# Epoch 00072: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 320ms/step - loss: 4.2155 - acc: 0.0324 - val_loss: 4.5624 - val_acc: 0.0170
# Epoch 73/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2068 - acc: 0.0329
# Epoch 00073: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 319ms/step - loss: 4.2068 - acc: 0.0329 - val_loss: 4.9814 - val_acc: 0.0096
# Epoch 74/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2038 - acc: 0.0352
# Epoch 00074: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 319ms/step - loss: 4.2038 - acc: 0.0352 - val_loss: 5.1509 - val_acc: 0.0157
# Epoch 75/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1660 - acc: 0.0397
# Epoch 00075: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 320ms/step - loss: 4.1660 - acc: 0.0397 - val_loss: 6.4019 - val_acc: 0.0056
# Epoch 76/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2108 - acc: 0.0347
# Epoch 00076: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 322ms/step - loss: 4.2108 - acc: 0.0347 - val_loss: 5.7315 - val_acc: 0.0059
# Epoch 77/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2459 - acc: 0.0296
# Epoch 00077: val_acc did not improve from 0.01882
# 237/237 [==============================] - 75s 318ms/step - loss: 4.2459 - acc: 0.0296 - val_loss: 5.1105 - val_acc: 0.0148
# Epoch 78/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2819 - acc: 0.0286
# Epoch 00078: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 320ms/step - loss: 4.2819 - acc: 0.0286 - val_loss: 4.8878 - val_acc: 0.0102
# Epoch 79/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1791 - acc: 0.0382
# Epoch 00079: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1791 - acc: 0.0382 - val_loss: 5.0250 - val_acc: 0.0142
# Epoch 80/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1228 - acc: 0.0384
# Epoch 00080: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1228 - acc: 0.0384 - val_loss: 5.3035 - val_acc: 0.0145
# Epoch 81/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2534 - acc: 0.0343
# Epoch 00081: val_acc did not improve from 0.01882
# 237/237 [==============================] - 75s 318ms/step - loss: 4.2534 - acc: 0.0343 - val_loss: 4.9230 - val_acc: 0.0145
# Epoch 82/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1401 - acc: 0.0370
# Epoch 00082: val_acc did not improve from 0.01882
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1401 - acc: 0.0370 - val_loss: 5.0379 - val_acc: 0.0148
# Epoch 83/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1163 - acc: 0.0380
# Epoch 00083: val_acc did not improve from 0.01882
# 237/237 [==============================] - 75s 318ms/step - loss: 4.1163 - acc: 0.0380 - val_loss: 5.1349 - val_acc: 0.0111
# Epoch 84/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1188 - acc: 0.0355
# Epoch 00084: val_acc did not improve from 0.01882
# 237/237 [==============================] - 77s 323ms/step - loss: 4.1188 - acc: 0.0355 - val_loss: 4.5937 - val_acc: 0.0151
# Epoch 85/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0876 - acc: 0.0403
# Epoch 00085: val_acc improved from 0.01882 to 0.01975, saving model to my_mobilenet_model_0.02_4.5007.h5
# 237/237 [==============================] - 76s 319ms/step - loss: 4.0876 - acc: 0.0403 - val_loss: 4.5007 - val_acc: 0.0197
# Epoch 86/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1764 - acc: 0.0335
# Epoch 00086: val_acc did not improve from 0.01975
# 237/237 [==============================] - 75s 318ms/step - loss: 4.1764 - acc: 0.0335 - val_loss: 5.8512 - val_acc: 0.0120
# Epoch 87/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1368 - acc: 0.0347
# Epoch 00087: val_acc did not improve from 0.01975
# 237/237 [==============================] - 75s 317ms/step - loss: 4.1368 - acc: 0.0347 - val_loss: 5.9682 - val_acc: 0.0108
# Epoch 88/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1419 - acc: 0.0337
# Epoch 00088: val_acc did not improve from 0.01975
# 237/237 [==============================] - 76s 320ms/step - loss: 4.1419 - acc: 0.0337 - val_loss: 4.6421 - val_acc: 0.0185
# Epoch 89/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1378 - acc: 0.0336
# Epoch 00089: val_acc improved from 0.01975 to 0.02283, saving model to my_mobilenet_model_0.02_4.5723.h5
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1378 - acc: 0.0336 - val_loss: 4.5723 - val_acc: 0.0228
# Epoch 90/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1036 - acc: 0.0385
# Epoch 00090: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1036 - acc: 0.0385 - val_loss: 4.7094 - val_acc: 0.0191
# Epoch 91/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0581 - acc: 0.0410
# Epoch 00091: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 319ms/step - loss: 4.0581 - acc: 0.0410 - val_loss: 4.5217 - val_acc: 0.0213
# Epoch 92/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0669 - acc: 0.0373
# Epoch 00092: val_acc did not improve from 0.02283
# 237/237 [==============================] - 77s 327ms/step - loss: 4.0669 - acc: 0.0373 - val_loss: 4.6072 - val_acc: 0.0207
# Epoch 93/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1170 - acc: 0.0356
# Epoch 00093: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.1170 - acc: 0.0356 - val_loss: 4.3680 - val_acc: 0.0182
# Epoch 94/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1005 - acc: 0.0380
# Epoch 00094: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.1005 - acc: 0.0380 - val_loss: 5.8793 - val_acc: 0.0105
# Epoch 95/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0857 - acc: 0.0345
# Epoch 00095: val_acc did not improve from 0.02283
# 237/237 [==============================] - 75s 318ms/step - loss: 4.0857 - acc: 0.0345 - val_loss: 4.8606 - val_acc: 0.0130
# Epoch 96/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0893 - acc: 0.0382
# Epoch 00096: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0893 - acc: 0.0382 - val_loss: 6.2765 - val_acc: 0.0108
# Epoch 97/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0913 - acc: 0.0377
# Epoch 00097: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0913 - acc: 0.0377 - val_loss: 4.6771 - val_acc: 0.0127
# Epoch 98/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1067 - acc: 0.0385
# Epoch 00098: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1067 - acc: 0.0385 - val_loss: 5.4806 - val_acc: 0.0127
# Epoch 99/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1463 - acc: 0.0304
# Epoch 00099: val_acc did not improve from 0.02283
# 237/237 [==============================] - 77s 324ms/step - loss: 4.1463 - acc: 0.0304 - val_loss: 4.6031 - val_acc: 0.0207
# Epoch 100/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0964 - acc: 0.0374
# Epoch 00100: val_acc did not improve from 0.02283
# 237/237 [==============================] - 75s 319ms/step - loss: 4.0964 - acc: 0.0374 - val_loss: 5.1132 - val_acc: 0.0207
# Epoch 101/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0703 - acc: 0.0343
# Epoch 00101: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0703 - acc: 0.0343 - val_loss: 6.1358 - val_acc: 0.0099
# Epoch 102/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1516 - acc: 0.0372
# Epoch 00102: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 321ms/step - loss: 4.1516 - acc: 0.0372 - val_loss: 4.8871 - val_acc: 0.0096
# Epoch 103/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1046 - acc: 0.0349
# Epoch 00103: val_acc did not improve from 0.02283
# 237/237 [==============================] - 75s 318ms/step - loss: 4.1046 - acc: 0.0349 - val_loss: 6.0380 - val_acc: 0.0176
# Epoch 104/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0543 - acc: 0.0398
# Epoch 00104: val_acc did not improve from 0.02283
# 237/237 [==============================] - 75s 318ms/step - loss: 4.0543 - acc: 0.0398 - val_loss: 6.1498 - val_acc: 0.0219
# Epoch 105/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0626 - acc: 0.0376
# Epoch 00105: val_acc did not improve from 0.02283
# 237/237 [==============================] - 77s 323ms/step - loss: 4.0626 - acc: 0.0376 - val_loss: 5.4622 - val_acc: 0.0173
# Epoch 106/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1014 - acc: 0.0370
# Epoch 00106: val_acc did not improve from 0.02283
# 237/237 [==============================] - 77s 324ms/step - loss: 4.1014 - acc: 0.0370 - val_loss: 4.6363 - val_acc: 0.0201
# Epoch 107/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0484 - acc: 0.0386
# Epoch 00107: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 323ms/step - loss: 4.0484 - acc: 0.0386 - val_loss: 4.8016 - val_acc: 0.0151
# Epoch 108/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1087 - acc: 0.0345
# Epoch 00108: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.1087 - acc: 0.0345 - val_loss: 4.5482 - val_acc: 0.0197
# Epoch 109/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1112 - acc: 0.0349
# Epoch 00109: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1112 - acc: 0.0349 - val_loss: 4.5313 - val_acc: 0.0210
# Epoch 110/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0868 - acc: 0.0386
# Epoch 00110: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0868 - acc: 0.0386 - val_loss: 4.9322 - val_acc: 0.0173
# Epoch 111/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0085 - acc: 0.0417
# Epoch 00111: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0085 - acc: 0.0417 - val_loss: 4.7037 - val_acc: 0.0151
# Epoch 112/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1017 - acc: 0.0360
# Epoch 00112: val_acc did not improve from 0.02283
# 237/237 [==============================] - 76s 320ms/step - loss: 4.1017 - acc: 0.0360 - val_loss: 4.6876 - val_acc: 0.0167
# Epoch 113/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0200 - acc: 0.0414
# Epoch 00113: val_acc improved from 0.02283 to 0.02438, saving model to my_mobilenet_model_0.02_4.8471.h5
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0200 - acc: 0.0414 - val_loss: 4.8471 - val_acc: 0.0244
# Epoch 114/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0079 - acc: 0.0380
# Epoch 00114: val_acc did not improve from 0.02438
# 237/237 [==============================] - 76s 319ms/step - loss: 4.0079 - acc: 0.0380 - val_loss: 5.1876 - val_acc: 0.0164
# Epoch 115/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9867 - acc: 0.0403
# Epoch 00115: val_acc did not improve from 0.02438
# 237/237 [==============================] - 78s 328ms/step - loss: 3.9867 - acc: 0.0403 - val_loss: 4.5826 - val_acc: 0.0197
# Epoch 116/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9746 - acc: 0.0446
# Epoch 00116: val_acc did not improve from 0.02438
# 237/237 [==============================] - 76s 319ms/step - loss: 3.9746 - acc: 0.0446 - val_loss: 4.5711 - val_acc: 0.0164
# Epoch 117/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0246 - acc: 0.0435
# Epoch 00117: val_acc did not improve from 0.02438
# 237/237 [==============================] - 75s 319ms/step - loss: 4.0246 - acc: 0.0435 - val_loss: 5.0380 - val_acc: 0.0207
# Epoch 118/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9889 - acc: 0.0397
# Epoch 00118: val_acc did not improve from 0.02438
# 237/237 [==============================] - 76s 321ms/step - loss: 3.9889 - acc: 0.0397 - val_loss: 4.4322 - val_acc: 0.0191
# Epoch 119/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9769 - acc: 0.0435
# Epoch 00119: val_acc improved from 0.02438 to 0.02530, saving model to my_mobilenet_model_0.03_5.3151.h5
# 237/237 [==============================] - 76s 321ms/step - loss: 3.9769 - acc: 0.0435 - val_loss: 5.3151 - val_acc: 0.0253
# Epoch 120/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0073 - acc: 0.0392
# Epoch 00120: val_acc did not improve from 0.02530
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0073 - acc: 0.0392 - val_loss: 5.5145 - val_acc: 0.0160
# Epoch 121/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9756 - acc: 0.0451
# Epoch 00121: val_acc did not improve from 0.02530
# 237/237 [==============================] - 75s 318ms/step - loss: 3.9756 - acc: 0.0451 - val_loss: 4.4829 - val_acc: 0.0204
# Epoch 122/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0223 - acc: 0.0388
# Epoch 00122: val_acc improved from 0.02530 to 0.02715, saving model to my_mobilenet_model_0.03_4.1722.h5
# 237/237 [==============================] - 76s 319ms/step - loss: 4.0223 - acc: 0.0388 - val_loss: 4.1722 - val_acc: 0.0272
# Epoch 123/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9717 - acc: 0.0418
# Epoch 00123: val_acc did not improve from 0.02715
# 237/237 [==============================] - 77s 323ms/step - loss: 3.9717 - acc: 0.0418 - val_loss: 5.2414 - val_acc: 0.0142
# Epoch 124/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9699 - acc: 0.0389
# Epoch 00124: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 3.9699 - acc: 0.0389 - val_loss: 4.5374 - val_acc: 0.0182
# Epoch 125/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9568 - acc: 0.0417
# Epoch 00125: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 3.9568 - acc: 0.0417 - val_loss: 4.9860 - val_acc: 0.0130
# Epoch 126/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9915 - acc: 0.0426
# Epoch 00126: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 3.9915 - acc: 0.0426 - val_loss: 4.9409 - val_acc: 0.0219
# Epoch 127/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1291 - acc: 0.0360
# Epoch 00127: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1291 - acc: 0.0360 - val_loss: 5.2922 - val_acc: 0.0099
# Epoch 128/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1847 - acc: 0.0343
# Epoch 00128: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1847 - acc: 0.0343 - val_loss: 5.1083 - val_acc: 0.0201
# Epoch 129/150
# 237/237 [==============================] - ETA: 0s - loss: 4.1454 - acc: 0.0364
# Epoch 00129: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 4.1454 - acc: 0.0364 - val_loss: 4.5759 - val_acc: 0.0145
# Epoch 130/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0055 - acc: 0.0410
# Epoch 00130: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0055 - acc: 0.0410 - val_loss: 5.4797 - val_acc: 0.0222
# Epoch 131/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9803 - acc: 0.0431
# Epoch 00131: val_acc did not improve from 0.02715
# 237/237 [==============================] - 77s 324ms/step - loss: 3.9803 - acc: 0.0431 - val_loss: 6.3089 - val_acc: 0.0216
# Epoch 132/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0301 - acc: 0.0431
# Epoch 00132: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 320ms/step - loss: 4.0301 - acc: 0.0431 - val_loss: 5.8879 - val_acc: 0.0117
# Epoch 133/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0061 - acc: 0.0389
# Epoch 00133: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 4.0061 - acc: 0.0389 - val_loss: 4.9592 - val_acc: 0.0191
# Epoch 134/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9206 - acc: 0.0447
# Epoch 00134: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 320ms/step - loss: 3.9206 - acc: 0.0447 - val_loss: 4.9874 - val_acc: 0.0142
# Epoch 135/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9442 - acc: 0.0422
# Epoch 00135: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 3.9442 - acc: 0.0422 - val_loss: 5.0024 - val_acc: 0.0225
# Epoch 136/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9039 - acc: 0.0438
# Epoch 00136: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 321ms/step - loss: 3.9039 - acc: 0.0438 - val_loss: 4.4494 - val_acc: 0.0188
# Epoch 137/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9135 - acc: 0.0437
# Epoch 00137: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 321ms/step - loss: 3.9135 - acc: 0.0437 - val_loss: 4.8447 - val_acc: 0.0133
# Epoch 138/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9356 - acc: 0.0472
# Epoch 00138: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 320ms/step - loss: 3.9356 - acc: 0.0472 - val_loss: 4.4281 - val_acc: 0.0194
# Epoch 139/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9724 - acc: 0.0393
# Epoch 00139: val_acc did not improve from 0.02715
# 237/237 [==============================] - 77s 324ms/step - loss: 3.9724 - acc: 0.0393 - val_loss: 4.8435 - val_acc: 0.0145
# Epoch 140/150
# 237/237 [==============================] - ETA: 0s - loss: 3.8553 - acc: 0.0474
# Epoch 00140: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 321ms/step - loss: 3.8553 - acc: 0.0474 - val_loss: 4.3209 - val_acc: 0.0256
# Epoch 141/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9762 - acc: 0.0411
# Epoch 00141: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 322ms/step - loss: 3.9762 - acc: 0.0411 - val_loss: 4.8123 - val_acc: 0.0179
# Epoch 142/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9272 - acc: 0.0437
# Epoch 00142: val_acc did not improve from 0.02715
# 237/237 [==============================] - 77s 324ms/step - loss: 3.9272 - acc: 0.0437 - val_loss: 5.9437 - val_acc: 0.0080
# Epoch 143/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9161 - acc: 0.0418
# Epoch 00143: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 3.9161 - acc: 0.0418 - val_loss: 6.1467 - val_acc: 0.0139
# Epoch 144/150
# 237/237 [==============================] - ETA: 0s - loss: 4.2316 - acc: 0.0402
# Epoch 00144: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 320ms/step - loss: 4.2316 - acc: 0.0402 - val_loss: 7.0598 - val_acc: 0.0102
# Epoch 145/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9486 - acc: 0.0455
# Epoch 00145: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 3.9486 - acc: 0.0455 - val_loss: 5.6258 - val_acc: 0.0173
# Epoch 146/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9112 - acc: 0.0482
# Epoch 00146: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 320ms/step - loss: 3.9112 - acc: 0.0482 - val_loss: 4.6563 - val_acc: 0.0231
# Epoch 147/150
# 237/237 [==============================] - ETA: 0s - loss: 4.0264 - acc: 0.0409
# Epoch 00147: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 322ms/step - loss: 4.0264 - acc: 0.0409 - val_loss: 7.6251 - val_acc: 0.0096
# Epoch 148/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9329 - acc: 0.0438
# Epoch 00148: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 320ms/step - loss: 3.9329 - acc: 0.0438 - val_loss: 5.7589 - val_acc: 0.0194
# Epoch 149/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9158 - acc: 0.0456
# Epoch 00149: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 319ms/step - loss: 3.9158 - acc: 0.0456 - val_loss: 5.7635 - val_acc: 0.0170
# Epoch 150/150
# 237/237 [==============================] - ETA: 0s - loss: 3.9079 - acc: 0.0441
# Epoch 00150: val_acc did not improve from 0.02715
# 237/237 [==============================] - 76s 321ms/step - loss: 3.9079 - acc: 0.0441 - val_loss: 5.9787 - val_acc: 0.0157
# Wall time: 3h 10min 52s
# 846

# %%
## 트레이닝 결과 곡선

## validation acc 곡선 그래프
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

## validation loss 곡선 그래프
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
## 저장된 모델 리스트 정렬

model_list = sorted([i for i in os.listdir() if "my_" in i])
model_list
# Out:
# ['my_mobilenet_model_0.00_5.3261.h5',
#  'my_mobilenet_model_0.00_5.6595.h5',
#  'my_mobilenet_model_0.00_5.7523.h5',
#  'my_mobilenet_model_0.00_5.8953.h5',
#  'my_mobilenet_model_0.00_5.9048.h5',
#  'my_mobilenet_model_0.00_5.9437.h5',
#  'my_mobilenet_model_0.01_4.7122.h5',
#  'my_mobilenet_model_0.01_4.9810.h5',
#  'my_mobilenet_model_0.01_5.0843.h5',
#  'my_mobilenet_model_0.01_5.2975.h5',
#  'my_mobilenet_model_0.01_5.4579.h5',
#  'my_mobilenet_model_0.02_4.5007.h5',
#  'my_mobilenet_model_0.02_4.5723.h5',
#  'my_mobilenet_model_0.02_4.7403.h5',
#  'my_mobilenet_model_0.02_4.8317.h5',
#  'my_mobilenet_model_0.02_4.8471.h5',
#  'my_mobilenet_model_0.03_4.1722.h5',
#  'my_mobilenet_model_0.03_5.3151.h5']

# %%
## BEST Model 선택

model.load_weights(model_list[-1])

# %%
# %%time
## Best Model 적용

test_generator.reset()
prediction = model.predict_generator(
    generator = test_generator,
    steps = get_steps(nb_test_samples, batch_size),
    verbose=1
)
# Out:
# WARNING:tensorflow:From <timed exec>:7: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 34/34 [==============================] - 5s 138ms/step
# Wall time: 5.23 s

# %% [markdown]
# ## 확인작업

# %%
## test 이미지 확인
f_name = "000009_26.png"

plt.figure(figsize=(20,10))

## 원본 이미지
plt.subplot(1, 3, 1)
origin_img = PIL.Image.open(os.path.join(TEST_IMG_PATH, f_name))
plt.title("Original Image - {}".format(f_name))
plt.imshow(origin_img)
plt.axis('off')

## Bounding Box 처리 된 이미지
plt.subplot(1, 3, 2)
boxing = make_boxing_img_test(f_name)
plt.title("Boxing Image - {}".format(f_name))
plt.imshow(boxing)
plt.axis('off')

## crop 된 이미지
plt.subplot(1, 3, 3)
crop = PIL.Image.open(os.path.join(TEST_CROP_PATH, f_name))
plt.title("crop - {}".format(f_name))
plt.imshow(crop)
plt.axis('off')

plt.show()

# %%
## 분류한 이미지의 추정 class 와 모델
## id = 추정 class 
## name 추정 모델 명

as1 = submission[submission['img_file'] == f_name]
df_class[df_class['id'] == int(as1.iloc[0][1])]

# %%
as1
# Out:
#        img_file class
# 3451  03452.jpg   149

# %% [markdown]
# # 간략 평가

# %%
EVAL_PATH = 'E:/coding/Stanford Cars Dataset'

all100 = pd.read_csv(os.path.join(EVAL_PATH, 'test_class.csv'))
all100 = all100[['img_file', 'class']]

# %%
score = []
for i in range(0,8040):
    if int(all100['class'][i]) == int(submission['class'][i]) :
        score.append(1)
    else:
        score.append(0)
print('정확도 : ' , score.count(1)/8040)
print('맞은 갯수 : ' , score.count(1), ' / 8040')
print('안맞은 갯수 : ',score.count(0))
# Out:
# 정확도 :  0.8259950248756219
# 맞은 갯수 :  6641  / 8040
# 안맞은 갯수 :  1399

# %% [markdown]
# ## 각 class 별 정확도 확인

# %%
classlist = pd.read_csv(os.path.join(EVAL_PATH, 'class.csv'))

# %%
totalclass = pd.read_csv(os.path.join(EVAL_PATH, 'totalclass.csv'))

# %%
totalclass = totalclass.sort_values(by=["class"], ascending=[True])
totalclass
# Out:
#        img_file  class  class1  a1
# 4116  04117.jpg      1       1   1
# 3245  03246.jpg      1       1   1
# 1198  01199.jpg      1       1   1
# 8034  08035.jpg      1       1   1
# 75    00076.jpg      1       1   1
# ...         ...    ...     ...  ..
# 932   00933.jpg    196     196   1
# 621   00622.jpg    196     110   0
# 5965  05966.jpg    196     196   1
# 5722  05723.jpg    196     196   1
# 1292  01293.jpg    196     136   0
#
# [8041 rows x 4 columns]

# %%
model_rate = pd.read_csv(os.path.join(EVAL_PATH, 'model_rate.csv'))
model_rate
# Out:
#       id                                             model      rate
# 0     71                       Chevrolet Express Van 2007   0.057143
# 1     10             Aston Martin Virage Convertible 2012   0.333333
# 2     14                              Audi TTS Coupe 2012   0.333333
# 3    104                    Ferrari 458 Italia Coupe 2012   0.452381
# 4     23                               Audi S4 Sedan 2012   0.461538
# ..   ...                                               ...       ...
# 163  130                  Hyundai Veloster Hatchback 2012   1.000000
# 164  141                        Infiniti G Coupe IPL 2012   1.000000
# 165  152  Lamborghini Gallardo LP 570 4 Superleggera 2012   1.000000
# 166  154                  Land Rover Range Rover SUV 2012   1.000000
# 167  159                           Mazda Tribute SUV 2011   1.000000
#
# [168 rows x 3 columns]

# %%
## 50% 미만 class
model_rate[model_rate['rate'] < 0.5]
# Out:
#     id                                  model      rate
# 0   71            Chevrolet Express Van 2007   0.057143
# 1   10  Aston Martin Virage Convertible 2012   0.333333
# 2   14                   Audi TTS Coupe 2012   0.333333
# 3  104         Ferrari 458 Italia Coupe 2012   0.452381
# 4   23                    Audi S4 Sedan 2012   0.461538

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 추가 파일 확인

# %%
n_test = pd.DataFrame(columns=['img_file', 'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2'])
re_test = pd.DataFrame(columns=['img_file', 'class'])

# %%
from PIL import Image

for i in os.listdir(N_TEST):
    img_open = Image.open(N_TEST + '/'+ i)
    img_array = np.asarray(img_open)
    file_name = i
    x_min = 0
    y_min = 0
    x_max = img_array.shape[1]
    y_max = img_array.shape[0]
    n_test = n_test.append(pd.DataFrame([[file_name, x_min, y_min, x_max, y_max]], 
                        columns=['img_file', 'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2']),
                        ignore_index=True)
    re_test = re_test.append(pd.DataFrame([[file_name]], 
                        columns=['img_file']),
                        ignore_index=True)

# %%
n_test
# Out:
#                   img_file bbox_x1 bbox_y1 bbox_x2 bbox_y2
# 0             00000007.jpg       0       0    3492    4656
# 1               000001.png       0       0    1751    2334
# 2             00000315.jpg       0       0    3492    4656
# 3             00000329.jpg       0       0    3492    4656
# 4               000006.png       0       0    1104    2334
# ..                     ...     ...     ...     ...     ...
# 95  03_20210519_073208.jpg       0       0    4032    3024
# 96         fix00000661.jpg       0       0    3024    4032
# 97         fix00000725.jpg       0       0    3024    4032
# 98         fix00000761.jpg       0       0    3024    4032
# 99         fix00000806.jpg       0       0    3024    4032
#
# [100 rows x 5 columns]

# %%
re_test
# re_test.head(50)
# re_test.tail(50)
# Out:
#                   img_file class
# 0             00000007.jpg   NaN
# 1               000001.png   NaN
# 2             00000315.jpg   NaN
# 3             00000329.jpg   NaN
# 4               000006.png   NaN
# ..                     ...   ...
# 95  03_20210519_073208.jpg   NaN
# 96         fix00000661.jpg   NaN
# 97         fix00000725.jpg   NaN
# 98         fix00000761.jpg   NaN
# 99         fix00000806.jpg   NaN
#
# [100 rows x 2 columns]

# %%
N_TEST = os.path.join(DATA_PATH, 'test_dj')
# n_test = pd.read_csv(os.path.join(DATA_PATH, 'test_dj.csv'))

# %%
N_TEST
# Out:
# 'D:/coding/data_set/lomin/train_copy2\\test_dj'

# %%
n_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
nb_n_test_samples = len(os.listdir(N_TEST))

# %%
n_test_generator = n_test_datagen.flow_from_dataframe(
    dataframe=n_test,
    directory=N_TEST,
    x_col='img_file',
    y_col=None,
    target_size= img_size,
    color_mode='rgb',
    class_mode=None,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 100 validated image filenames.

# %%
# %%time
## Best Model 적용

n_test_generator.reset()
prediction = model.predict_generator(
    generator = n_test_generator,
    steps = get_steps(nb_n_test_samples, batch_size),
    verbose=1
)
# Out:
# 4/4 [==============================] - 4s 965ms/step
# Wall time: 7.7 s

# %% [markdown]
# ## 추가 결과표 작성

# %%
## 결과를 표로 작성

predicted_class_indices=np.argmax(prediction, axis=1)

# Generator class dictionary mapping
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

# # submission2 = pd.read_csv(os.path.join(DATA_PATH, 'sample_submission2.csv'))
# submission2 = re_test
# submission2["class"] = predictions



# # submission2.to_csv("submission2.csv", index=False)
# submission2.head()

for i in range(len(os.listdir(N_TEST))) :
    re_test['class'][i] = predictions[i]

re_test
# Out:
#                   img_file class
# 0             00000007.jpg   173
# 1               000001.png   173
# 2             00000315.jpg   156
# 3             00000329.jpg   173
# 4               000006.png   173
# ..                     ...   ...
# 95  03_20210519_073208.jpg   271
# 96         fix00000661.jpg   342
# 97         fix00000725.jpg    92
# 98         fix00000761.jpg   173
# 99         fix00000806.jpg   173
#
# [100 rows x 2 columns]

# %%
import cv2
import matplotlib.pyplot as plt

k = 55
ro_angle = int(re_test['class'][k])
f_name = os.listdir(N_TEST)[k]

plt.figure(figsize=(20,10))

img_rgb = cv2.imread(os.path.join(N_TEST, f_name))
img_rgb = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB)
h, w, c = img_rgb.shape

ro_center = int(w/2), int(h/2) # 정수
new_h, new_w = h, w

img_ro = cv2.getRotationMatrix2D(ro_center, ro_angle, 1) # 1은 확대/축소값
re_ro = cv2.warpAffine(img_rgb, img_ro, (new_h, new_w))

# 출력
plt.subplot(1, 2, 1) # 1행 2열에서 1번째 열
plt.title("Original Image - {}".format(f_name))
plt.imshow(img_rgb)

plt.subplot(1, 2, 2) # 1행 2열에서 2번째 열
plt.title("Result Image - rotation {}".format(ro_angle))
plt.imshow(re_ro)

plt.show()
